# %%
using Pkg
Pkg.add(Pkg.PackageSpec(;name="IonSim", version="0.5.1"))
Pkg.add(Pkg.PackageSpec(;name="QuantumOptics", version="1.0.15"))
# Out:
#    Resolving package versions...
#    Installed GR_jll ─────────────────────────── v0.73.17+0
#    Installed libfdk_aac_jll ─────────────────── v2.0.4+0
#    Installed x265_jll ───────────────────────── v3.5.0+0
#    Installed JpegTurbo_jll ──────────────────── v3.1.1+0
#    Installed Libmount_jll ───────────────────── v2.41.0+0
#    Installed libdecor_jll ───────────────────── v0.2.2+0
#    Installed OffsetArrays ───────────────────── v1.17.0
#    Installed LRUCache ───────────────────────── v1.6.2
#    Installed HypergeometricFunctions ────────── v0.3.28
#    Installed StatsFuns ──────────────────────── v1.5.0
#    Installed FFTW ───────────────────────────── v1.9.0
#    Installed LERC_jll ───────────────────────── v4.0.1+0
#    Installed Accessors ──────────────────────── v0.1.42
#    Installed Compiler ───────────────────────── v0.1.1
#    Installed DSP ────────────────────────────── v0.8.4
#    Installed LoggingExtras ──────────────────── v1.1.0
#    Installed FastGaussQuadrature ────────────── v1.0.2
#    Installed Opus_jll ───────────────────────── v1.5.2+0
#    Installed Xorg_xkbcomp_jll ───────────────── v1.4.7+0
#    Installed Preferences ────────────────────── v1.4.3
#    Installed RelocatableFolders ─────────────── v1.0.1
#    Installed NonlinearSolve ─────────────────── v3.14.0
#    Installed Unitful ────────────────────────── v1.23.1
#    Installed Measures ───────────────────────── v0.3.2
#    Installed TimerOutputs ───────────────────── v0.5.29
#    Installed PDMats ─────────────────────────── v0.11.35
#    Installed Contour ────────────────────────── v0.6.3
#    Installed StaticArrays ───────────────────── v1.9.13
#    Installed Grisu ──────────────────────────── v1.0.2
#    Installed ConcurrentUtilities ────────────── v2.5.0
#    Installed GSL_jll ────────────────────────── v2.8.1+0
#    Installed Xorg_xcb_util_wm_jll ───────────── v0.4.2+0
#    Installed Polyester ──────────────────────── v0.7.18
#    Installed ColorSchemes ───────────────────── v3.30.0
#    Installed PlotUtils ──────────────────────── v1.4.3
#    Installed Xorg_xcb_util_image_jll ────────── v0.4.1+0
#    Installed QuantumOptics ──────────────────── v1.0.15
#    Installed EnumX ──────────────────────────── v1.0.5
#    Installed RecipesPipeline ────────────────── v0.6.12
#    Installed RationalRoots ──────────────────── v0.2.1
#    Installed RecursiveArrayTools ────────────── v3.34.1
#    Installed OpenSSL ────────────────────────── v1.5.0
#    Installed GR ─────────────────────────────── v0.73.17
#    Installed Xorg_libSM_jll ─────────────────── v1.2.6+0
#    Installed MaybeInplace ───────────────────── v0.1.4
#    Installed FunctionWrappers ───────────────── v1.1.3
#    Installed OrdinaryDiffEqCore ─────────────── v1.26.2
#    Installed HTTP ───────────────────────────── v1.10.17
#    Installed DelimitedFiles ─────────────────── v1.9.1
#    Installed libsodium_jll ──────────────────── v1.0.21+0
#    Installed Xorg_xcb_util_jll ──────────────── v0.4.1+0
#    Installed Fontconfig_jll ─────────────────── v2.16.0+0
#    Installed Cairo_jll ──────────────────────── v1.18.5+0
#    Installed CodeTracking ───────────────────── v1.3.9
#    Installed TriangularSolve ────────────────── v0.2.1
#    Installed Polynomials ────────────────────── v4.1.0
#    Installed RandomNumbers ──────────────────── v1.6.0
#    Installed Xorg_libXinerama_jll ───────────── v1.1.6+0
#    Installed IntelOpenMP_jll ────────────────── v2025.0.4+0
#    Installed Xorg_libxkbfile_jll ────────────── v1.1.3+0
#    Installed Xorg_libXau_jll ────────────────── v1.0.13+0
#    Installed SLEEFPirates ───────────────────── v0.6.43
#    Installed HalfIntegers ───────────────────── v1.6.0
#    Installed EpollShim_jll ──────────────────── v0.0.20230411+1
#    Installed Static ─────────────────────────── v1.2.0
#    Installed Distances ──────────────────────── v0.10.12
#    Installed Missings ───────────────────────── v1.2.0
#    Installed FFMPEG ─────────────────────────── v0.4.2
#    Installed IrrationalConstants ────────────── v0.2.4
#    Installed FastPower ──────────────────────── v1.1.3
#    Installed KrylovKit ──────────────────────── v0.6.1
#    Installed FiniteDiff ─────────────────────── v2.27.0
#    Installed MuladdMacro ────────────────────── v0.2.4
#    Installed SIMDTypes ──────────────────────── v0.1.0
#    Installed TupleTools ─────────────────────── v1.6.0
#    Installed JSON ───────────────────────────── v0.21.4
#    Installed Pango_jll ──────────────────────── v1.56.3+0
#    Installed Showoff ────────────────────────── v1.0.3
#    Installed Functors ───────────────────────── v0.4.12
#    Installed DiffEqBase ─────────────────────── v6.174.0
#    Installed ArnoldiMethod ──────────────────── v0.4.0
#    Installed SciMLBase ──────────────────────── v2.77.2
#    Installed Revise ─────────────────────────── v3.8.0
#    Installed CpuId ──────────────────────────── v0.3.1
#    Installed PtrArrays ──────────────────────── v1.3.0
#    Installed SimpleUnPack ───────────────────── v1.1.0
#    Installed Bessels ────────────────────────── v0.2.8
#    Installed SpecialFunctions ───────────────── v2.5.1
#    Installed xkbcommon_jll ──────────────────── v1.9.2+0
#    Installed LinearMaps ─────────────────────── v3.11.4
#    Installed ADTypes ────────────────────────── v1.15.0
#    Installed LinearSolve ────────────────────── v2.30.1
#    Installed NLsolve ────────────────────────── v4.5.1
#    Installed SimpleBufferStream ─────────────── v1.2.0
#    Installed OrdinaryDiffEq ─────────────────── v6.87.0
#    Installed XZ_jll ─────────────────────────── v5.8.1+0
#    Installed Bzip2_jll ──────────────────────── v1.0.9+0
#    Installed LoweredCodeUtils ───────────────── v3.4.1
#    Installed Xorg_xcb_util_keysyms_jll ──────── v0.4.1+0
#    Installed IJulia ─────────────────────────── v1.29.0
#    Installed IfElse ─────────────────────────── v0.1.1
#    Installed HarfBuzz_jll ───────────────────── v8.5.1+0
#    Installed PlotThemes ─────────────────────── v3.3.0
#    Installed WignerSymbols ──────────────────── v2.0.0
#    Installed NaNMath ────────────────────────── v1.1.3
#    Installed StaticArraysCore ───────────────── v1.4.3
#    Installed StringEncodings ────────────────── v0.3.7
#    Installed SimpleNonlinearSolve ───────────── v1.12.5
#    Installed DiffEqNoiseProcess ─────────────── v5.24.1
#    Installed PyPlot ─────────────────────────── v2.11.6
#    Installed LZO_jll ────────────────────────── v2.10.3+0
#    Installed SoftGlobalScope ────────────────── v1.1.0
#    Installed TranscodingStreams ─────────────── v0.11.3
#    Installed ThreadingUtilities ─────────────── v0.5.5
#    Installed fzf_jll ────────────────────────── v0.61.1+0
#    Installed FriBidi_jll ────────────────────── v1.0.17+0
#    Installed GSL ────────────────────────────── v1.0.1
#    Installed JumpProcesses ──────────────────── v9.14.3
#    Installed Random123 ──────────────────────── v1.7.1
#    Installed ManualMemory ───────────────────── v0.1.8
#    Installed Graphs ─────────────────────────── v1.13.0
#    Installed ZeroMQ_jll ─────────────────────── v4.3.6+0
#    Installed FastExpm ───────────────────────── v1.1.0
#    Installed NLSolversBase ──────────────────── v7.8.3
#    Installed Rmath_jll ──────────────────────── v0.5.1+0
#    Installed MbedTLS ────────────────────────── v1.1.9
#    Installed LevyArea ───────────────────────── v1.0.0
#    Installed UnicodeFun ─────────────────────── v0.4.1
#    Installed UnsafeArrays ───────────────────── v1.0.8
#    Installed GLFW_jll ───────────────────────── v3.4.0+2
#    Installed CommonSubexpressions ───────────── v0.3.1
#    Installed LazyArrays ─────────────────────── v2.6.1
#    Installed x264_jll ───────────────────────── v2021.5.5+0
#    Installed DataStructures ─────────────────── v0.18.22
#    Installed FreeType2_jll ──────────────────── v2.13.4+0
#    Installed JLFzf ──────────────────────────── v0.1.11
#    Installed Colors ─────────────────────────── v0.13.1
#    Installed ExprTools ──────────────────────── v0.1.10
#    Installed StatsAPI ───────────────────────── v1.7.1
#    Installed StridedViews ───────────────────── v0.4.1
#    Installed Compat ─────────────────────────── v4.17.0
#    Installed CommonWorldInvalidations ───────── v1.0.0
#    Installed CodecZlib ──────────────────────── v0.7.8
#    Installed libpng_jll ─────────────────────── v1.6.50+0
#    Installed StatsBase ──────────────────────── v0.34.5
#    Installed StaticArrayInterface ───────────── v1.8.0
#    Installed Xorg_libxcb_jll ────────────────── v1.17.1+0
#    Installed ExceptionUnwrapping ────────────── v0.1.11
#    Installed ArrayLayouts ───────────────────── v1.11.1
#    Installed SciMLStructures ────────────────── v1.7.0
#    Installed mtdev_jll ──────────────────────── v1.1.7+0
#    Installed libaom_jll ─────────────────────── v3.11.0+0
#    Installed Scratch ────────────────────────── v1.3.0
#    Installed BitTwiddlingConvenienceFunctions ─ v0.1.6
#    Installed Dbus_jll ───────────────────────── v1.16.2+0
#    Installed DiffRules ──────────────────────── v1.15.1
#    Installed oneTBB_jll ─────────────────────── v2022.0.0+0
#    Installed Plots ──────────────────────────── v1.40.16
#    Installed ColorTypes ─────────────────────── v0.12.1
#    Installed eudev_jll ──────────────────────── v3.2.14+0
#    Installed FunctionWrappersWrappers ───────── v0.1.3
#    Installed GenericSchur ───────────────────── v0.5.5
#    Installed Conda ──────────────────────────── v1.10.2
#    Installed Xorg_libXext_jll ───────────────── v1.3.7+0
#    Installed StochasticDiffEq ───────────────── v6.72.1
#    Installed PrettyTables ───────────────────── v2.4.0
#    Installed LayoutPointers ─────────────────── v0.1.17
#    Installed Expat_jll ──────────────────────── v2.6.5+0
#    Installed TableTraits ────────────────────── v1.0.1
#    Installed DiffResults ────────────────────── v1.1.0
#    Installed Inflate ────────────────────────── v0.1.5
#    Installed Zstd_jll ───────────────────────── v1.5.7+1
#    Installed Xorg_xcb_util_cursor_jll ───────── v0.1.5+0
#    Installed TensorCore ─────────────────────── v0.1.1
#    Installed ZMQ ────────────────────────────── v1.4.1
#    Installed Parsers ────────────────────────── v2.8.3
#    Installed DiffEqCallbacks ────────────────── v2.37.0
#    Installed JuliaInterpreter ───────────────── v0.10.3
#    Installed PositiveFactorizations ─────────── v0.2.4
#    Installed Setfield ───────────────────────── v1.1.2
#    Installed PyCall ─────────────────────────── v1.96.4
#    Installed MKL_jll ────────────────────────── v2025.0.1+1
#    Installed Format ─────────────────────────── v1.3.7
#    Installed Libtiff_jll ────────────────────── v4.7.1+0
#    Installed SciMLOperators ─────────────────── v0.3.12
#    Installed LoopVectorization ──────────────── v0.12.172
#    Installed AbstractFFTs ───────────────────── v1.5.0
#    Installed ExproniconLite ─────────────────── v0.10.14
#    Installed JLLWrappers ────────────────────── v1.7.0
#    Installed ColorVectorSpace ───────────────── v0.11.0
#    Installed DataValueInterfaces ────────────── v1.0.0
#    Installed QuantumInterface ───────────────── v0.3.10
#    Installed Libffi_jll ─────────────────────── v3.4.7+0
#    Installed OrderedCollections ─────────────── v1.8.1
#    Installed EnzymeCore ─────────────────────── v0.7.8
#    Installed libevdev_jll ───────────────────── v1.13.4+0
#    Installed Xorg_libXrender_jll ────────────── v0.9.12+0
#    Installed ConstructionBase ───────────────── v1.6.0
#    Installed QuantumOpticsBase ──────────────── v0.4.22
#    Installed Ogg_jll ────────────────────────── v1.3.6+0
#    Installed ChainRulesCore ─────────────────── v1.25.2
#    Installed FastClosures ───────────────────── v0.3.2
#    Installed libinput_jll ───────────────────── v1.28.1+0
#    Installed Combinatorics ──────────────────── v1.0.3
#    Installed Xorg_libXi_jll ─────────────────── v1.8.3+0
#    Installed PolyesterWeave ─────────────────── v0.2.2
#    Installed Vulkan_Loader_jll ──────────────── v1.3.243+0
#    Installed ArrayInterface ─────────────────── v7.19.0
#    Installed LineSearches ───────────────────── v7.4.0
#    Installed Reexport ───────────────────────── v1.2.2
#    Installed Qt6Declarative_jll ─────────────── v6.8.2+1
#    Installed PreallocationTools ─────────────── v0.4.27
#    Installed Qt6ShaderTools_jll ─────────────── v6.8.2+1
#    Installed LogExpFunctions ────────────────── v0.3.29
#    Installed KLU ────────────────────────────── v0.6.0
#    Installed AliasTables ────────────────────── v1.1.3
#    Installed FastLapackInterface ────────────── v2.0.4
#    Installed Krylov ─────────────────────────── v0.9.10
#    Installed CloseOpenIntervals ─────────────── v0.1.13
#    Installed Strided ────────────────────────── v2.3.1
#    Installed OpenSpecFun_jll ────────────────── v0.5.6+0
#    Installed PackageExtensionCompat ─────────── v1.0.2
#    Installed FFTW_jll ───────────────────────── v3.3.11+0
#    Installed Xorg_libXcursor_jll ────────────── v1.2.4+0
#    Installed CommonSolve ────────────────────── v0.2.4
#    Installed MacroTools ─────────────────────── v0.5.16
#    Installed CompositionsBase ───────────────── v0.1.2
#    Installed InverseFunctions ───────────────── v0.1.17
#    Installed UnPack ─────────────────────────── v1.0.2
#    Installed DocStringExtensions ────────────── v0.9.5
#    Installed DifferentiationInterface ───────── v0.6.26
#    Installed SimpleTraits ───────────────────── v0.9.4
#    Installed Libuuid_jll ────────────────────── v2.41.0+0
#    Installed YAML ───────────────────────────── v0.4.14
#    Installed GPUArraysCore ──────────────────── v0.1.6
#    Installed ExponentialUtilities ───────────── v1.27.0
#    Installed Xorg_xcb_util_renderutil_jll ───── v0.3.10+0
#    Installed Xorg_libICE_jll ────────────────── v1.1.2+0
#    Installed Crayons ────────────────────────── v4.1.1
#    Installed RandomMatrices ─────────────────── v0.5.5
#    Installed StableRNGs ─────────────────────── v1.0.3
#    Installed Adapt ──────────────────────────── v4.3.0
#    Installed Rmath ──────────────────────────── v0.8.0
#    Installed libass_jll ─────────────────────── v0.15.2+0
#    Installed XML2_jll ───────────────────────── v2.13.6+1
#    Installed StrideArraysCore ───────────────── v0.5.7
#    Installed Pixman_jll ─────────────────────── v0.44.2+0
#    Installed IntegerMathUtils ───────────────── v0.1.3
#    Installed VectorizationBase ──────────────── v0.21.71
#    Installed Graphite2_jll ──────────────────── v1.3.15+0
#    Installed Latexify ───────────────────────── v0.16.8
#    Installed Wayland_jll ────────────────────── v1.23.1+2
#    Installed Arpack_jll ─────────────────────── v3.5.1+1
#    Installed Xorg_xtrans_jll ────────────────── v1.6.0+0
#    Installed IonSim ─────────────────────────── v0.5.1
#    Installed RuntimeGeneratedFunctions ──────── v0.5.15
#    Installed Jieko ──────────────────────────── v0.2.1
#    Installed IterTools ──────────────────────── v1.10.0
#    Installed OpenSSL_jll ────────────────────── v3.5.1+0
#    Installed Moshi ──────────────────────────── v0.3.7
#    Installed Xorg_xkeyboard_config_jll ──────── v2.44.0+0
#    Installed Tables ─────────────────────────── v1.12.1
#    Installed FFMPEG_jll ─────────────────────── v4.4.4+1
#    Installed CPUSummary ─────────────────────── v0.2.6
#    Installed BitFlags ───────────────────────── v0.1.9
#    Installed VertexSafeGraphs ───────────────── v0.2.0
#    Installed LLVMOpenMP_jll ─────────────────── v18.1.8+0
#    Installed Xorg_libXrandr_jll ─────────────── v1.5.5+0
#    Installed DataAPI ────────────────────────── v1.16.0
#    Installed Optim ──────────────────────────── v1.11.0
#    Installed FixedPointNumbers ──────────────── v0.8.5
#    Installed Primes ─────────────────────────── v0.5.7
#    Installed RecipesBase ────────────────────── v1.3.4
#    Installed LAME_jll ───────────────────────── v3.100.3+0
#    Installed PolynomialRoots ────────────────── v1.0.0
#    Installed ConcreteStructs ────────────────── v0.2.3
#    Installed Xorg_libXfixes_jll ─────────────── v6.0.1+0
#    Installed Qt6Wayland_jll ─────────────────── v6.8.2+1
#    Installed PrecompileTools ────────────────── v1.2.1
#    Installed IterativeSolvers ───────────────── v0.9.4
#    Installed GettextRuntime_jll ─────────────── v0.22.4+0
#    Installed IteratorInterfaceExtensions ────── v1.0.0
#    Installed Libiconv_jll ───────────────────── v1.18.0+0
#    Installed TruncatedStacktraces ───────────── v1.4.0
#    Installed URIs ───────────────────────────── v1.6.1
#    Installed Qt6Base_jll ────────────────────── v6.8.2+1
#    Installed HostCPUFeatures ────────────────── v0.1.17
#    Installed VersionParsing ─────────────────── v1.3.0
#    Installed LaTeXStrings ───────────────────── v1.4.0
#    Installed Arpack ─────────────────────────── v0.5.3
#    Installed libvorbis_jll ──────────────────── v1.3.8+0
#    Installed Glib_jll ───────────────────────── v2.84.3+0
#    Installed SymbolicIndexingInterface ──────── v0.3.41
#    Installed Libglvnd_jll ───────────────────── v1.7.1+1
#    Installed PoissonRandom ──────────────────── v0.4.4
#    Installed ForwardDiff ────────────────────── v0.10.38
#    Installed QuadGK ─────────────────────────── v2.11.2
#    Installed FillArrays ─────────────────────── v1.13.0
#    Installed Xorg_libXdmcp_jll ──────────────── v1.1.6+0
#    Installed ResettableStacks ───────────────── v1.1.1
#    Installed FastBroadcast ──────────────────── v0.3.5
#    Installed Requires ───────────────────────── v1.3.1
#    Installed Distributions ──────────────────── v0.25.120
#    Installed Xorg_libX11_jll ────────────────── v1.8.12+0
#    Installed Parameters ─────────────────────── v0.12.3
#    Installed UnitfulLatexify ────────────────── v1.7.0
#    Installed StringManipulation ─────────────── v0.4.1
#    Installed RecursiveFactorization ─────────── v0.2.23
#    Installed Unzip ──────────────────────────── v0.2.0
#    Installed Sparspak ───────────────────────── v0.3.12
#    Installed SparseDiffTools ────────────────── v2.26.0
#    Installed SortingAlgorithms ──────────────── v1.2.1
#   No Changes to `C:\Users\jewoo\.julia\environments\v1.10\Project.toml`
#   No Changes to `C:\Users\jewoo\.julia\environments\v1.10\Manifest.toml`
#     Building Conda ─→ `C:\Users\jewoo\.julia\scratchspaces\44cfe95a-1eb2-52ea-b672-e2afdf69b78f\b19db3927f0db4151cb86d073689f2428e524576\build.log`
#     Building PyCall → `C:\Users\jewoo\.julia\scratchspaces\44cfe95a-1eb2-52ea-b672-e2afdf69b78f\9816a3826b0ebf49ab4926e2b18842ad8b5c8f04\build.log`
#     Building IJulia → `C:\Users\jewoo\.julia\scratchspaces\44cfe95a-1eb2-52ea-b672-e2afdf69b78f\9e60d328aa8060368d6dadd24b644d0ebaf0c1cb\build.log`
# Precompiling packages...
#     568.8 ms  ✓ SimpleUnPack
#     547.4 ms  ✓ IteratorInterfaceExtensions
#     559.4 ms  ✓ ConcreteStructs
#     590.1 ms  ✓ LaTeXStrings
#     578.4 ms  ✓ StatsAPI
#     689.3 ms  ✓ ADTypes
#     803.9 ms  ✓ FunctionWrappers
#     516.9 ms  ✓ Contour
#     606.2 ms  ✓ InverseFunctions
#     519.1 ms  ✓ SoftGlobalScope
#     644.4 ms  ✓ Measures
#    1100.7 ms  ✓ OffsetArrays
#     453.8 ms  ✓ DataValueInterfaces
#     669.6 ms  ✓ Compat
#     638.0 ms  ✓ DocStringExtensions
#    1312.2 ms  ✓ Grisu
#     475.1 ms  ✓ SimpleBufferStream
#    1806.1 ms  ✓ ExproniconLite
#     612.5 ms  ✓ DelimitedFiles
#     734.0 ms  ✓ CpuId
#     538.1 ms  ✓ Compiler
#    1384.9 ms  ✓ URIs
#     541.5 ms  ✓ ExprTools
#     514.8 ms  ✓ RationalRoots
#     544.1 ms  ✓ UnPack
#     539.7 ms  ✓ IntegerMathUtils
#     798.0 ms  ✓ ConcurrentUtilities
#     454.7 ms  ✓ CommonSolve
ms  ✓ RecursiveArrayTools → RecursiveArrayToolsSparseArraysExt
#   11115.5 ms  ✓ FastPower → FastPowerForwardDiffExt
#   10223.5 ms  ✓ Unitful → ForwardDiffExt
#   10462.9 ms  ✓ DifferentiationInterface → DifferentiationInterfaceForwardDiffExt
#     898.3 ms  ✓ FastBroadcast
#    9462.0 ms  ✓ PreallocationTools
#     851.5 ms  ✓ Revise → DistributedExt
#    8820.1 ms  ✓ NLSolversBase
#    3280.0 ms  ✓ PlotThemes
#     789.7 ms  ✓ xkbcommon_jll
#    4156.5 ms  ✓ RecipesPipeline
#    1282.9 ms  ✓ libass_jll
#    1250.9 ms  ✓ Pango_jll
#    1557.0 ms  ✓ Distributions → DistributionsChainRulesCoreExt
#    2261.2 ms  ✓ Distributions → DistributionsTestExt
#    3444.1 ms  ✓ SparseDiffTools
#    1521.5 ms  ✓ DSP → OffsetArraysExt
#    1371.0 ms  ✓ RecursiveArrayTools → RecursiveArrayToolsForwardDiffExt
#     698.2 ms  ✓ Vulkan_Loader_jll
#    1325.0 ms  ✓ RecursiveArrayTools → RecursiveArrayToolsFastBroadcastExt
#     645.5 ms  ✓ libdecor_jll
#    3447.3 ms  ✓ PyPlot
#    2647.3 ms  ✓ LineSearches
#    2343.2 ms  ✓ FFMPEG_jll
#    1535.6 ms  ✓ Qt6Base_jll
#     717.3 ms  ✓ GLFW_jll
#    1796.4 ms  ✓ SparseDiffTools → SparseDiffToolsPolyesterExt
#    2747.3 ms  ✓ RandomMatrices
#    1471.3 ms  ✓ FFMPEG
#    2360.7 ms  ✓ NLsolve
#    3216.5 ms  ✓ Qt6ShaderTools_jll
#    3015.2 ms  ✓ GR_jll
#    3968.3 ms  ✓ Optim
#    9627.6 ms  ✓ SciMLBase
#    3953.4 ms  ✓ QuantumOpticsBase
#    2999.9 ms  ✓ Qt6Declarative_jll
#    1416.8 ms  ✓ SciMLBase → SciMLBaseChainRulesCoreExt
#     483.3 ms  ✓ Qt6Wayland_jll
#    2363.9 ms  ✓ SciMLBase → SciMLBasePyCallExt
#    3307.0 ms  ✓ DiffEqBase
#    1275.3 ms  ✓ DiffEqBase → DiffEqBaseSparseArraysExt
#    3396.9 ms  ✓ GR
#    2767.3 ms  ✓ DiffEqBase → DiffEqBaseChainRulesCoreExt
#    2945.2 ms  ✓ DiffEqBase → DiffEqBaseUnitfulExt
#    3020.7 ms  ✓ DiffEqBase → DiffEqBaseDistributionsExt
#    3859.3 ms  ✓ DiffEqBase → DiffEqBaseForwardDiffExt
#   18926.4 ms  ✓ LoopVectorization
#    5286.0 ms  ✓ JumpProcesses
#     965.6 ms  ✓ LoopVectorization → SpecialFunctionsExt
#    5959.7 ms  ✓ OrdinaryDiffEqCore
#    1073.5 ms  ✓ TriangularSolve
#    1096.2 ms  ✓ LoopVectorization → ForwardDiffExt
#    3177.7 ms  ✓ DiffEqCallbacks
#    3980.4 ms  ✓ DiffEqNoiseProcess
#    1665.2 ms  ✓ OrdinaryDiffEqCore → OrdinaryDiffEqCoreEnzymeCoreExt
#    6319.1 ms  ✓ RecursiveFactorization
#   23991.7 ms  ✓ SimpleNonlinearSolve
#    1921.5 ms  ✓ SimpleNonlinearSolve → SimpleNonlinearSolveChainRulesCoreExt
#   23263.3 ms  ✓ LinearSolve
#    2184.7 ms  ✓ LinearSolve → LinearSolveRecursiveArrayToolsExt
#            ✗ NonlinearSolve
#    2669.9 ms  ✓ LinearSolve → LinearSolveKrylovKitExt
#    2749.4 ms  ✓ LinearSolve → LinearSolveIterativeSolversExt
#            ✗ NonlinearSolve → NonlinearSolveNLsolveExt
#            ✗ OrdinaryDiffEq
#   49267.9 ms  ✓ Plots
#    2855.9 ms  ✓ Plots → UnitfulExt
#            ✗ StochasticDiffEq
#    2224.0 ms  ✓ Plots → IJuliaExt
#            ✗ QuantumOptics
#            ✗ IonSim
#   397 dependencies successfully precompiled in 185 seconds. 12 already precompiled.
#   19 dependencies precompiled but different versions are currently loaded. Restart julia to access the new versions
#   6 dependencies errored.
#   For a report of the errors see `julia> err`. To retry use `pkg> precompile`
#    Resolving package versions...
#   No Changes to `C:\Users\jewoo\.julia\environments\v1.10\Project.toml`
#   No Changes to `C:\Users\jewoo\.julia\environments\v1.10\Manifest.toml`
# Precompiling packages...
#            ✗ NonlinearSolve
#            ✗ NonlinearSolve → NonlinearSolveNLsolveExt
#            ✗ OrdinaryDiffEq
#            ✗ StochasticDiffEq
#            ✗ QuantumOptics
#            ✗ IonSim
#   0 dependencies successfully precompiled in 73 seconds. 409 already precompiled.
#   6 dependencies errored.
#   For a report of the errors see `julia> err`. To retry use `pkg> precompile`

# %%
Pkg.add("Revise")
Pkg.add("PyPlot")
Pkg.add("StochasticDiffEq")
Pkg.add("DSP")
# Out:
#    Resolving package versions...
#   No Changes to `C:\Users\jewoo\.julia\environments\v1.10\Project.toml`
#   No Changes to `C:\Users\jewoo\.julia\environments\v1.10\Manifest.toml`
# Precompiling packages...
#            ✗ NonlinearSolve
#            ✗ NonlinearSolve → NonlinearSolveNLsolveExt
#            ✗ OrdinaryDiffEq
#            ✗ StochasticDiffEq
#            ✗ QuantumOptics
#            ✗ IonSim
#   0 dependencies successfully precompiled in 32 seconds. 409 already precompiled.
#   6 dependencies errored.
#   For a report of the errors see `julia> err`. To retry use `pkg> precompile`
#    Resolving package versions...
#   No Changes to `C:\Users\jewoo\.julia\environments\v1.10\Project.toml`
#   No Changes to `C:\Users\jewoo\.julia\environments\v1.10\Manifest.toml`
# Precompiling packages...
#            ✗ NonlinearSolve
#            ✗ NonlinearSolve → NonlinearSolveNLsolveExt
#            ✗ OrdinaryDiffEq
#            ✗ StochasticDiffEq
#            ✗ QuantumOptics
#            ✗ IonSim
#   0 dependencies successfully precompiled in 31 seconds. 409 already precompiled.
#   6 dependencies errored.
#   For a report of the errors see `julia> err`. To retry use `pkg> precompile`
#    Resolving package versions...
#   No Changes to `C:\Users\jewoo\.julia\environments\v1.10\Project.toml`
#   No Changes to `C:\Users\jewoo\.julia\environments\v1.10\Manifest.toml`
# Precompiling packages...
#            ✗ NonlinearSolve
#            ✗ NonlinearSolve → NonlinearSolveNLsolveExt
#            ✗ OrdinaryDiffEq
#            ✗ StochasticDiffEq
#            ✗ QuantumOptics
#            ✗ IonSim
#   0 dependencies successfully precompiled in 33 seconds. 409 already precompiled.
#   6 dependencies errored.
#   For a report of the errors see `julia> err`. To retry use `pkg> precompile`
#    Resolving package versions...
#   No Changes to `C:\Users\jewoo\.julia\environments\v1.10\Project.toml`
#   No Changes to `C:\Users\jewoo\.julia\environments\v1.10\Manifest.toml`
# Precompiling packages...
#            ✗ NonlinearSolve
#            ✗ NonlinearSolve → NonlinearSolveNLsolveExt
#            ✗ OrdinaryDiffEq
#            ✗ StochasticDiffEq
#            ✗ QuantumOptics
#            ✗ IonSim
#   0 dependencies successfully precompiled in 32 seconds. 409 already precompiled.
#   6 dependencies errored.
#   For a report of the errors see `julia> err`. To retry use `pkg> precompile`

# %%
using Revise
using IonSim
using QuantumOptics: timeevolution, stochastic, Basis

import PyPlot
const plt = PyPlot;
# Out:
# Precompiling packages...
#            ✗ NonlinearSolve
#            ✗ NonlinearSolve → NonlinearSolveNLsolveExt
#            ✗ OrdinaryDiffEq
#            ✗ StochasticDiffEq
#            ✗ QuantumOptics
# Info Given IonSim was explicitly requested, output will be shown live
# ERROR: LoadError: UndefVarError: `AbstractNonlinearTerminationMode` not defined
# Stacktrace:
#  [1] include
#    @ .\Base.jl:495 [inlined]
#  [2] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
#    @ Base .\loading.jl:2292
#  [3] top-level scope
#    @ stdin:4
# in expression starting at C:\Users\jewoo\.julia\packages\NonlinearSolve\sETeN\src\NonlinearSolve.jl:1
# in expression starting at stdin:4
# ERROR: LoadError: Failed to precompile NonlinearSolve [8913a72c-1f9b-4ce2-8d82-65094dcecaec] to "C:\\Users\\jewoo\\.julia\\compiled\\v1.10\\NonlinearSolve\\jl_1F66.tmp".
# Stacktrace:
#   [1] error(s::String)
#     @ Base .\error.jl:35
#   [2] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool)
#     @ Base .\loading.jl:2539
#   [3] compilecache
#     @ .\loading.jl:2411 [inlined]
#   [4] (::Base.var"#971#972"{Base.PkgId})()
#     @ Base .\loading.jl:2044
#   [5] mkpidlock(f::Base.var"#971#972"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
#     @ FileWatching.Pidfile C:\Users\jewoo\AppData\Local\Programs\Julia-1.10.10\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:93
#   [6] #mkpidlock#6
#     @ C:\Users\jewoo\AppData\Local\Programs\Julia-1.10.10\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:88 [inlined]
#   [7] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
#     @ FileWatching.Pidfile C:\Users\jewoo\AppData\Local\Programs\Julia-1.10.10\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:111
#   [8] #invokelatest#2
#     @ .\essentials.jl:894 [inlined]
#   [9] invokelatest
#     @ .\essentials.jl:889 [inlined]
#  [10] maybe_cachefile_lock(f::Base.var"#971#972"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
#     @ Base .\loading.jl:3054
#  [11] maybe_cachefile_lock
#     @ .\loading.jl:3051 [inlined]
#  [12] _require(pkg::Base.PkgId, env::String)
#     @ Base .\loading.jl:2040
#  [13] __require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1882
#  [14] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [15] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [16] _require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1873
#  [17] macro expansion
#     @ .\loading.jl:1860 [inlined]
#  [18] macro expansion
#     @ .\lock.jl:267 [inlined]
#  [19] __require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1823
#  [20] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [21] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [22] require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1816
#  [23] include
#     @ .\Base.jl:495 [inlined]
#  [24] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
#     @ Base .\loading.jl:2292
#  [25] top-level scope
#     @ stdin:4
# in expression starting at C:\Users\jewoo\.julia\packages\OrdinaryDiffEq\s27pa\src\OrdinaryDiffEq.jl:1
# in expression starting at stdin:4
# ERROR: LoadError: Failed to precompile OrdinaryDiffEq [1dea7af3-3e70-54e6-95c3-0bf5283fa5ed] to "C:\\Users\\jewoo\\.julia\\compiled\\v1.10\\OrdinaryDiffEq\\jl_140C.tmp".
# Stacktrace:
#   [1] error(s::String)
#     @ Base .\error.jl:35
#   [2] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool)
#     @ Base .\loading.jl:2539
#   [3] compilecache
#     @ .\loading.jl:2411 [inlined]
#   [4] (::Base.var"#971#972"{Base.PkgId})()
#     @ Base .\loading.jl:2044
#   [5] mkpidlock(f::Base.var"#971#972"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
#     @ FileWatching.Pidfile C:\Users\jewoo\AppData\Local\Programs\Julia-1.10.10\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:93
#   [6] #mkpidlock#6
#     @ C:\Users\jewoo\AppData\Local\Programs\Julia-1.10.10\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:88 [inlined]
#   [7] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
#     @ FileWatching.Pidfile C:\Users\jewoo\AppData\Local\Programs\Julia-1.10.10\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:111
#   [8] #invokelatest#2
#     @ .\essentials.jl:894 [inlined]
#   [9] invokelatest
#     @ .\essentials.jl:889 [inlined]
#  [10] maybe_cachefile_lock(f::Base.var"#971#972"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
#     @ Base .\loading.jl:3054
#  [11] maybe_cachefile_lock
#     @ .\loading.jl:3051 [inlined]
#  [12] _require(pkg::Base.PkgId, env::String)
#     @ Base .\loading.jl:2040
#  [13] __require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1882
#  [14] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [15] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [16] _require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1873
#  [17] macro expansion
#     @ .\loading.jl:1860 [inlined]
#  [18] macro expansion
#     @ .\lock.jl:267 [inlined]
#  [19] __require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1823
#  [20] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [21] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [22] require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1816
#  [23] include(mod::Module, _path::String)
#     @ Base .\Base.jl:495
#  [24] include(x::String)
#     @ QuantumOptics.timeevolution C:\Users\jewoo\.julia\packages\QuantumOptics\9adUY\src\QuantumOptics.jl:18
#  [25] top-level scope
#     @ C:\Users\jewoo\.julia\packages\QuantumOptics\9adUY\src\QuantumOptics.jl:21
#  [26] include
#     @ .\Base.jl:495 [inlined]
#  [27] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
#     @ Base .\loading.jl:2292
#  [28] top-level scope
#     @ stdin:4
# in expression starting at C:\Users\jewoo\.julia\packages\QuantumOptics\9adUY\src\timeevolution_base.jl:4
# in expression starting at C:\Users\jewoo\.julia\packages\QuantumOptics\9adUY\src\QuantumOptics.jl:1
# in expression starting at stdin:4
# ERROR: LoadError: Failed to precompile QuantumOptics [6e0679c1-51ea-5a7c-ac74-d61b76210b0c] to "C:\\Users\\jewoo\\.julia\\compiled\\v1.10\\QuantumOptics\\jl_D94.tmp".
# Stacktrace:
#   [1] error(s::String)
#     @ Base .\error.jl:35
#   [2] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool)
#     @ Base .\loading.jl:2539
#   [3] compilecache
#     @ .\loading.jl:2411 [inlined]
#   [4] (::Base.var"#971#972"{Base.PkgId})()
#     @ Base .\loading.jl:2044
#   [5] mkpidlock(f::Base.var"#971#972"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
#     @ FileWatching.Pidfile C:\Users\jewoo\AppData\Local\Programs\Julia-1.10.10\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:93
#   [6] #mkpidlock#6
#     @ C:\Users\jewoo\AppData\Local\Programs\Julia-1.10.10\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:88 [inlined]
#   [7] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
#     @ FileWatching.Pidfile C:\Users\jewoo\AppData\Local\Programs\Julia-1.10.10\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:111
#   [8] #invokelatest#2
#     @ .\essentials.jl:894 [inlined]
#   [9] invokelatest
#     @ .\essentials.jl:889 [inlined]
#  [10] maybe_cachefile_lock(f::Base.var"#971#972"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
#     @ Base .\loading.jl:3054
#  [11] maybe_cachefile_lock
#     @ .\loading.jl:3051 [inlined]
#  [12] _require(pkg::Base.PkgId, env::String)
#     @ Base .\loading.jl:2040
#  [13] __require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1882
#  [14] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [15] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [16] _require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1873
#  [17] macro expansion
#     @ .\loading.jl:1860 [inlined]
#  [18] macro expansion
#     @ .\lock.jl:267 [inlined]
#  [19] __require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1823
#  [20] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [21] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [22] require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1816
#  [23] include
#     @ .\Base.jl:495 [inlined]
#  [24] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::Nothing)
#     @ Base .\loading.jl:2292
#  [25] top-level scope
#     @ stdin:4
# in expression starting at C:\Users\jewoo\.julia\packages\IonSim\s9QSU\src\IonSim.jl:1
# in expression starting at stdin:4
#            ✗ IonSim
#   0 dependencies successfully precompiled in 33 seconds. 385 already precompiled.
# The following 3 direct dependencies failed to precompile:
#
# StochasticDiffEq
#
# Failed to precompile StochasticDiffEq [789caeaf-c7a9-5a7d-9973-96adeb23e2a0] to "C:\\Users\\jewoo\\.julia\\compiled\\v1.10\\StochasticDiffEq\\jl_D877.tmp".
# ERROR: LoadError: UndefVarError: `AbstractNonlinearTerminationMode` not defined
# Stacktrace:
#  [1] include
#    @ .\Base.jl:495 [inlined]
#  [2] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
#    @ Base .\loading.jl:2292
#  [3] top-level scope
#    @ stdin:4
# in expression starting at C:\Users\jewoo\.julia\packages\NonlinearSolve\sETeN\src\NonlinearSolve.jl:1
# in expression starting at stdin:4
# ERROR: LoadError: Failed to precompile NonlinearSolve [8913a72c-1f9b-4ce2-8d82-65094dcecaec] to "C:\\Users\\jewoo\\.julia\\compiled\\v1.10\\NonlinearSolve\\jl_E23E.tmp".
# Stacktrace:
#   [1] error(s::String)
#     @ Base .\error.jl:35
#   [2] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool)
#     @ Base .\loading.jl:2539
#   [3] compilecache
#     @ .\loading.jl:2411 [inlined]
#   [4] (::Base.var"#971#972"{Base.PkgId})()
#     @ Base .\loading.jl:2044
#   [5] mkpidlock(f::Base.var"#971#972"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
#     @ FileWatching.Pidfile C:\Users\jewoo\AppData\Local\Programs\Julia-1.10.10\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:93
#   [6] #mkpidlock#6
#     @ C:\Users\jewoo\AppData\Local\Programs\Julia-1.10.10\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:88 [inlined]
#   [7] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
#     @ FileWatching.Pidfile C:\Users\jewoo\AppData\Local\Programs\Julia-1.10.10\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:111
#   [8] #invokelatest#2
#     @ .\essentials.jl:894 [inlined]
#   [9] invokelatest
#     @ .\essentials.jl:889 [inlined]
#  [10] maybe_cachefile_lock(f::Base.var"#971#972"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
#     @ Base .\loading.jl:3054
#  [11] maybe_cachefile_lock
#     @ .\loading.jl:3051 [inlined]
#  [12] _require(pkg::Base.PkgId, env::String)
#     @ Base .\loading.jl:2040
#  [13] __require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1882
#  [14] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [15] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [16] _require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1873
#  [17] macro expansion
#     @ .\loading.jl:1860 [inlined]
#  [18] macro expansion
#     @ .\lock.jl:267 [inlined]
#  [19] __require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1823
#  [20] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [21] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [22] require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1816
#  [23] include
#     @ .\Base.jl:495 [inlined]
#  [24] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
#     @ Base .\loading.jl:2292
#  [25] top-level scope
#     @ stdin:4
# in expression starting at C:\Users\jewoo\.julia\packages\OrdinaryDiffEq\s27pa\src\OrdinaryDiffEq.jl:1
# in expression starting at stdin:4
# ERROR: LoadError: Failed to precompile OrdinaryDiffEq [1dea7af3-3e70-54e6-95c3-0bf5283fa5ed] to "C:\\Users\\jewoo\\.julia\\compiled\\v1.10\\OrdinaryDiffEq\\jl_D741.tmp".
# Stacktrace:
#   [1] error(s::String)
#     @ Base .\error.jl:35
#   [2] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool)
#     @ Base .\loading.jl:2539
#   [3] compilecache
#     @ .\loading.jl:2411 [inlined]
#   [4] (::Base.var"#971#972"{Base.PkgId})()
#     @ Base .\loading.jl:2044
#   [5] mkpidlock(f::Base.var"#971#972"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
#     @ FileWatching.Pidfile C:\Users\jewoo\AppData\Local\Programs\Julia-1.10.10\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:93
#   [6] #mkpidlock#6
#     @ C:\Users\jewoo\AppData\Local\Programs\Julia-1.10.10\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:88 [inlined]
#   [7] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
#     @ FileWatching.Pidfile C:\Users\jewoo\AppData\Local\Programs\Julia-1.10.10\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:111
#   [8] #invokelatest#2
#     @ .\essentials.jl:894 [inlined]
#   [9] invokelatest
#     @ .\essentials.jl:889 [inlined]
#  [10] maybe_cachefile_lock(f::Base.var"#971#972"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
#     @ Base .\loading.jl:3054
#  [11] maybe_cachefile_lock
#     @ .\loading.jl:3051 [inlined]
#  [12] _require(pkg::Base.PkgId, env::String)
#     @ Base .\loading.jl:2040
#  [13] __require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1882
#  [14] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [15] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [16] _require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1873
#  [17] macro expansion
#     @ .\loading.jl:1860 [inlined]
#  [18] macro expansion
#     @ .\lock.jl:267 [inlined]
#  [19] __require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1823
#  [20] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [21] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [22] require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1816
#  [23] include
#     @ .\Base.jl:495 [inlined]
#  [24] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::Nothing)
#     @ Base .\loading.jl:2292
#  [25] top-level scope
#     @ stdin:4
# in expression starting at C:\Users\jewoo\.julia\packages\StochasticDiffEq\vo3vZ\src\StochasticDiffEq.jl:1
# in expression starting at stdin:4
# QuantumOptics
#
# Failed to precompile QuantumOptics [6e0679c1-51ea-5a7c-ac74-d61b76210b0c] to "C:\\Users\\jewoo\\.julia\\compiled\\v1.10\\QuantumOptics\\jl_F5C6.tmp".
# ERROR: LoadError: UndefVarError: `AbstractNonlinearTerminationMode` not defined
# Stacktrace:
#  [1] include
#    @ .\Base.jl:495 [inlined]
#  [2] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
#    @ Base .\loading.jl:2292
#  [3] top-level scope
#    @ stdin:4
# in expression starting at C:\Users\jewoo\.julia\packages\NonlinearSolve\sETeN\src\NonlinearSolve.jl:1
# in expression starting at stdin:4
# ERROR: LoadError: Failed to precompile NonlinearSolve [8913a72c-1f9b-4ce2-8d82-65094dcecaec] to "C:\\Users\\jewoo\\.julia\\compiled\\v1.10\\NonlinearSolve\\jl_17.tmp".
# Stacktrace:
#   [1] error(s::String)
#     @ Base .\error.jl:35
#   [2] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool)
#     @ Base .\loading.jl:2539
#   [3] compilecache
#     @ .\loading.jl:2411 [inlined]
#   [4] (::Base.var"#971#972"{Base.PkgId})()
#     @ Base .\loading.jl:2044
#   [5] mkpidlock(f::Base.var"#971#972"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
#     @ FileWatching.Pidfile C:\Users\jewoo\AppData\Local\Programs\Julia-1.10.10\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:93
#   [6] #mkpidlock#6
#     @ C:\Users\jewoo\AppData\Local\Programs\Julia-1.10.10\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:88 [inlined]
#   [7] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
#     @ FileWatching.Pidfile C:\Users\jewoo\AppData\Local\Programs\Julia-1.10.10\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:111
#   [8] #invokelatest#2
#     @ .\essentials.jl:894 [inlined]
#   [9] invokelatest
#     @ .\essentials.jl:889 [inlined]
#  [10] maybe_cachefile_lock(f::Base.var"#971#972"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
#     @ Base .\loading.jl:3054
#  [11] maybe_cachefile_lock
#     @ .\loading.jl:3051 [inlined]
#  [12] _require(pkg::Base.PkgId, env::String)
#     @ Base .\loading.jl:2040
#  [13] __require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1882
#  [14] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [15] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [16] _require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1873
#  [17] macro expansion
#     @ .\loading.jl:1860 [inlined]
#  [18] macro expansion
#     @ .\lock.jl:267 [inlined]
#  [19] __require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1823
#  [20] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [21] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [22] require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1816
#  [23] include
#     @ .\Base.jl:495 [inlined]
#  [24] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
#     @ Base .\loading.jl:2292
#  [25] top-level scope
#     @ stdin:4
# in expression starting at C:\Users\jewoo\.julia\packages\OrdinaryDiffEq\s27pa\src\OrdinaryDiffEq.jl:1
# in expression starting at stdin:4
# ERROR: LoadError: Failed to precompile OrdinaryDiffEq [1dea7af3-3e70-54e6-95c3-0bf5283fa5ed] to "C:\\Users\\jewoo\\.julia\\compiled\\v1.10\\OrdinaryDiffEq\\jl_F5C6.tmp".
# Stacktrace:
#   [1] error(s::String)
#     @ Base .\error.jl:35
#   [2] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool)
#     @ Base .\loading.jl:2539
#   [3] compilecache
#     @ .\loading.jl:2411 [inlined]
#   [4] (::Base.var"#971#972"{Base.PkgId})()
#     @ Base .\loading.jl:2044
#   [5] mkpidlock(f::Base.var"#971#972"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
#     @ FileWatching.Pidfile C:\Users\jewoo\AppData\Local\Programs\Julia-1.10.10\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:93
#   [6] #mkpidlock#6
#     @ C:\Users\jewoo\AppData\Local\Programs\Julia-1.10.10\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:88 [inlined]
#   [7] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
#     @ FileWatching.Pidfile C:\Users\jewoo\AppData\Local\Programs\Julia-1.10.10\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:111
#   [8] #invokelatest#2
#     @ .\essentials.jl:894 [inlined]
#   [9] invokelatest
#     @ .\essentials.jl:889 [inlined]
#  [10] maybe_cachefile_lock(f::Base.var"#971#972"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
#     @ Base .\loading.jl:3054
#  [11] maybe_cachefile_lock
#     @ .\loading.jl:3051 [inlined]
#  [12] _require(pkg::Base.PkgId, env::String)
#     @ Base .\loading.jl:2040
#  [13] __require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1882
#  [14] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [15] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [16] _require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1873
#  [17] macro expansion
#     @ .\loading.jl:1860 [inlined]
#  [18] macro expansion
#     @ .\lock.jl:267 [inlined]
#  [19] __require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1823
#  [20] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [21] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [22] require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1816
#  [23] include(mod::Module, _path::String)
#     @ Base .\Base.jl:495
#  [24] include(x::String)
#     @ QuantumOptics.timeevolution C:\Users\jewoo\.julia\packages\QuantumOptics\9adUY\src\QuantumOptics.jl:18
#  [25] top-level scope
#     @ C:\Users\jewoo\.julia\packages\QuantumOptics\9adUY\src\QuantumOptics.jl:21
#  [26] include
#     @ .\Base.jl:495 [inlined]
#  [27] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::Nothing)
#     @ Base .\loading.jl:2292
#  [28] top-level scope
#     @ stdin:4
# in expression starting at C:\Users\jewoo\.julia\packages\QuantumOptics\9adUY\src\timeevolution_base.jl:4
# in expression starting at C:\Users\jewoo\.julia\packages\QuantumOptics\9adUY\src\QuantumOptics.jl:1
# in expression starting at stdin:4
#
# IonSim
#
# Failed to precompile IonSim [511e77fe-ab93-41f7-8f07-8f89809c6435] to "C:\\Users\\jewoo\\.julia\\compiled\\v1.10\\IonSim\\jl_12E6.tmp".
# ERROR: LoadError: UndefVarError: `AbstractNonlinearTerminationMode` not defined
# Stacktrace:
#  [1] include
#    @ .\Base.jl:495 [inlined]
#  [2] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
#    @ Base .\loading.jl:2292
#  [3] top-level scope
#    @ stdin:4
# in expression starting at C:\Users\jewoo\.julia\packages\NonlinearSolve\sETeN\src\NonlinearSolve.jl:1
# in expression starting at stdin:4
# ERROR: LoadError: Failed to precompile NonlinearSolve [8913a72c-1f9b-4ce2-8d82-65094dcecaec] to "C:\\Users\\jewoo\\.julia\\compiled\\v1.10\\NonlinearSolve\\jl_1F66.tmp".
# Stacktrace:
#   [1] error(s::String)
#     @ Base .\error.jl:35
#   [2] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool)
#     @ Base .\loading.jl:2539
#   [3] compilecache
#     @ .\loading.jl:2411 [inlined]
#   [4] (::Base.var"#971#972"{Base.PkgId})()
#     @ Base .\loading.jl:2044
#   [5] mkpidlock(f::Base.var"#971#972"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
#     @ FileWatching.Pidfile C:\Users\jewoo\AppData\Local\Programs\Julia-1.10.10\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:93
#   [6] #mkpidlock#6
#     @ C:\Users\jewoo\AppData\Local\Programs\Julia-1.10.10\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:88 [inlined]
#   [7] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
#     @ FileWatching.Pidfile C:\Users\jewoo\AppData\Local\Programs\Julia-1.10.10\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:111
#   [8] #invokelatest#2
#     @ .\essentials.jl:894 [inlined]
#   [9] invokelatest
#     @ .\essentials.jl:889 [inlined]
#  [10] maybe_cachefile_lock(f::Base.var"#971#972"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
#     @ Base .\loading.jl:3054
#  [11] maybe_cachefile_lock
#     @ .\loading.jl:3051 [inlined]
#  [12] _require(pkg::Base.PkgId, env::String)
#     @ Base .\loading.jl:2040
#  [13] __require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1882
#  [14] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [15] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [16] _require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1873
#  [17] macro expansion
#     @ .\loading.jl:1860 [inlined]
#  [18] macro expansion
#     @ .\lock.jl:267 [inlined]
#  [19] __require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1823
#  [20] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [21] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [22] require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1816
#  [23] include
#     @ .\Base.jl:495 [inlined]
#  [24] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
#     @ Base .\loading.jl:2292
#  [25] top-level scope
#     @ stdin:4
# in expression starting at C:\Users\jewoo\.julia\packages\OrdinaryDiffEq\s27pa\src\OrdinaryDiffEq.jl:1
# in expression starting at stdin:4
# ERROR: LoadError: Failed to precompile OrdinaryDiffEq [1dea7af3-3e70-54e6-95c3-0bf5283fa5ed] to "C:\\Users\\jewoo\\.julia\\compiled\\v1.10\\OrdinaryDiffEq\\jl_140C.tmp".
# Stacktrace:
#   [1] error(s::String)
#     @ Base .\error.jl:35
#   [2] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool)
#     @ Base .\loading.jl:2539
#   [3] compilecache
#     @ .\loading.jl:2411 [inlined]
#   [4] (::Base.var"#971#972"{Base.PkgId})()
#     @ Base .\loading.jl:2044
#   [5] mkpidlock(f::Base.var"#971#972"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
#     @ FileWatching.Pidfile C:\Users\jewoo\AppData\Local\Programs\Julia-1.10.10\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:93
#   [6] #mkpidlock#6
#     @ C:\Users\jewoo\AppData\Local\Programs\Julia-1.10.10\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:88 [inlined]
#   [7] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
#     @ FileWatching.Pidfile C:\Users\jewoo\AppData\Local\Programs\Julia-1.10.10\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:111
#   [8] #invokelatest#2
#     @ .\essentials.jl:894 [inlined]
#   [9] invokelatest
#     @ .\essentials.jl:889 [inlined]
#  [10] maybe_cachefile_lock(f::Base.var"#971#972"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
#     @ Base .\loading.jl:3054
#  [11] maybe_cachefile_lock
#     @ .\loading.jl:3051 [inlined]
#  [12] _require(pkg::Base.PkgId, env::String)
#     @ Base .\loading.jl:2040
#  [13] __require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1882
#  [14] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [15] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [16] _require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1873
#  [17] macro expansion
#     @ .\loading.jl:1860 [inlined]
#  [18] macro expansion
#     @ .\lock.jl:267 [inlined]
#  [19] __require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1823
#  [20] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [21] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [22] require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1816
#  [23] include(mod::Module, _path::String)
#     @ Base .\Base.jl:495
#  [24] include(x::String)
#     @ QuantumOptics.timeevolution C:\Users\jewoo\.julia\packages\QuantumOptics\9adUY\src\QuantumOptics.jl:18
#  [25] top-level scope
#     @ C:\Users\jewoo\.julia\packages\QuantumOptics\9adUY\src\QuantumOptics.jl:21
#  [26] include
#     @ .\Base.jl:495 [inlined]
#  [27] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
#     @ Base .\loading.jl:2292
#  [28] top-level scope
#     @ stdin:4
# in expression starting at C:\Users\jewoo\.julia\packages\QuantumOptics\9adUY\src\timeevolution_base.jl:4
# in expression starting at C:\Users\jewoo\.julia\packages\QuantumOptics\9adUY\src\QuantumOptics.jl:1
# in expression starting at stdin:4
# ERROR: LoadError: Failed to precompile QuantumOptics [6e0679c1-51ea-5a7c-ac74-d61b76210b0c] to "C:\\Users\\jewoo\\.julia\\compiled\\v1.10\\QuantumOptics\\jl_D94.tmp".
# Stacktrace:
#   [1] error(s::String)
#     @ Base .\error.jl:35
#   [2] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool)
#     @ Base .\loading.jl:2539
#   [3] compilecache
#     @ .\loading.jl:2411 [inlined]
#   [4] (::Base.var"#971#972"{Base.PkgId})()
#     @ Base .\loading.jl:2044
#   [5] mkpidlock(f::Base.var"#971#972"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
#     @ FileWatching.Pidfile C:\Users\jewoo\AppData\Local\Programs\Julia-1.10.10\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:93
#   [6] #mkpidlock#6
#     @ C:\Users\jewoo\AppData\Local\Programs\Julia-1.10.10\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:88 [inlined]
#   [7] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
#     @ FileWatching.Pidfile C:\Users\jewoo\AppData\Local\Programs\Julia-1.10.10\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:111
#   [8] #invokelatest#2
#     @ .\essentials.jl:894 [inlined]
#   [9] invokelatest
#     @ .\essentials.jl:889 [inlined]
#  [10] maybe_cachefile_lock(f::Base.var"#971#972"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
#     @ Base .\loading.jl:3054
#  [11] maybe_cachefile_lock
#     @ .\loading.jl:3051 [inlined]
#  [12] _require(pkg::Base.PkgId, env::String)
#     @ Base .\loading.jl:2040
#  [13] __require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1882
#  [14] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [15] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [16] _require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1873
#  [17] macro expansion
#     @ .\loading.jl:1860 [inlined]
#  [18] macro expansion
#     @ .\lock.jl:267 [inlined]
#  [19] __require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1823
#  [20] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [21] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [22] require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1816
#  [23] include
#     @ .\Base.jl:495 [inlined]
#  [24] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::Nothing)
#     @ Base .\loading.jl:2292
#  [25] top-level scope
#     @ stdin:4
# in expression starting at C:\Users\jewoo\.julia\packages\IonSim\s9QSU\src\IonSim.jl:1
# in expression starting at stdin:4
#
# Stacktrace:
#   [1] _precompilepkgs(pkgs::Vector{String}, internal_call::Bool, strict::Bool, warn_loaded::Bool, timing::Bool, _from_loading::Bool, io::IOContext{IO}, fancyprint::Bool, manifest::Bool)
#     @ Pkg.API.Precompilation C:\Users\jewoo\AppData\Local\Programs\Julia-1.10.10\share\julia\stdlib\v1.10\Pkg\src\precompilation.jl:1029
#   [2] #precompilepkgs#5
#     @ C:\Users\jewoo\AppData\Local\Programs\Julia-1.10.10\share\julia\stdlib\v1.10\Pkg\src\precompilation.jl:332 [inlined]
#   [3] (::Pkg.API.var"#225#226"{Bool, Bool, Bool, Bool, Bool, Vector{Pkg.Types.PackageSpec}})()
#     @ Pkg.API C:\Users\jewoo\AppData\Local\Programs\Julia-1.10.10\share\julia\stdlib\v1.10\Pkg\src\API.jl:1090
#   [4] activate(f::Pkg.API.var"#225#226"{Bool, Bool, Bool, Bool, Bool, Vector{Pkg.Types.PackageSpec}}, new_project::String)
#     @ Pkg.API C:\Users\jewoo\AppData\Local\Programs\Julia-1.10.10\share\julia\stdlib\v1.10\Pkg\src\API.jl:1315
#   [5] precompile(ctx::Pkg.Types.Context, pkgs::Vector{Pkg.Types.PackageSpec}; internal_call::Bool, strict::Bool, warn_loaded::Bool, already_instantiated::Bool, timing::Bool, _from_loading::Bool, kwargs::@Kwargs{io::IJulia.IJuliaStdio{Base.PipeEndpoint}})
#     @ Pkg.API C:\Users\jewoo\AppData\Local\Programs\Julia-1.10.10\share\julia\stdlib\v1.10\Pkg\src\API.jl:1088
#   [6] precompile(pkgs::Vector{Pkg.Types.PackageSpec}; io::IJulia.IJuliaStdio{Base.PipeEndpoint}, kwargs::@Kwargs{_from_loading::Bool})
#     @ Pkg.API C:\Users\jewoo\AppData\Local\Programs\Julia-1.10.10\share\julia\stdlib\v1.10\Pkg\src\API.jl:159
#   [7] precompile
#     @ C:\Users\jewoo\AppData\Local\Programs\Julia-1.10.10\share\julia\stdlib\v1.10\Pkg\src\API.jl:147 [inlined]
#   [8] #precompile#114
#     @ C:\Users\jewoo\AppData\Local\Programs\Julia-1.10.10\share\julia\stdlib\v1.10\Pkg\src\API.jl:146 [inlined]
#   [9] #invokelatest#2
#     @ .\essentials.jl:894 [inlined]
#  [10] invokelatest
#     @ .\essentials.jl:889 [inlined]
#  [11] _require(pkg::Base.PkgId, env::String)
#     @ Base .\loading.jl:2033
#  [12] __require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1882
#  [13] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [14] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [15] _require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1873
#  [16] macro expansion
#     @ .\loading.jl:1860 [inlined]
#  [17] macro expansion
#     @ .\lock.jl:267 [inlined]
#  [18] __require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1823
#  [19] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [20] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [21] require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1816

# %%
# Out:
#    Resolving package versions...
#   No Changes to `C:\Users\jewoo\.julia\environments\v1.10\Project.toml`
#   No Changes to `C:\Users\jewoo\.julia\environments\v1.10\Manifest.toml`
# Precompiling packages...
#            ✗ NonlinearSolve
#            ✗ NonlinearSolve → NonlinearSolveNLsolveExt
#            ✗ OrdinaryDiffEq
#            ✗ StochasticDiffEq
#            ✗ QuantumOptics
#            ✗ IonSim
#   0 dependencies successfully precompiled in 32 seconds. 409 already precompiled.
#   6 dependencies errored.
#   For a report of the errors see `julia> err`. To retry use `pkg> precompile`

# %%
using Pkg
Pkg.add("Revise")
Pkg.add("IonSim")
Pkg.add("QuantumOptics")
using Revise
using IonSim
using QuantumOptics: timeevolution, stochastic, Basis
# Out:
#    Resolving package versions...
#   No Changes to `C:\Users\jewoo\.julia\environments\v1.10\Project.toml`
#   No Changes to `C:\Users\jewoo\.julia\environments\v1.10\Manifest.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\jewoo\.julia\environments\v1.10\Project.toml`
#   No Changes to `C:\Users\jewoo\.julia\environments\v1.10\Manifest.toml`
#    Resolving package versions...
#     Updating `C:\Users\jewoo\.julia\environments\v1.10\Project.toml`
#   [6e0679c1] + QuantumOptics v1.2.3
#   No Changes to `C:\Users\jewoo\.julia\environments\v1.10\Manifest.toml`

# %%
using Pkg
Pkg.add("StochasticDiffEq")
Pkg.add("DSP")
# Out:
#    Resolving package versions...
#     Updating `C:\Users\jewoo\.julia\environments\v1.10\Project.toml`
#   [789caeaf] + StochasticDiffEq v6.80.0
#   No Changes to `C:\Users\jewoo\.julia\environments\v1.10\Manifest.toml`
#    Resolving package versions...
#    Installed Polynomials ─ v4.1.0
#    Installed IterTools ─── v1.10.0
#    Installed Bessels ───── v0.2.8
#    Installed DSP ───────── v0.8.4
#     Updating `C:\Users\jewoo\.julia\environments\v1.10\Project.toml`
#   [717857b8] + DSP v0.8.4
#     Updating `C:\Users\jewoo\.julia\environments\v1.10\Manifest.toml`
#   [0e736298] + Bessels v0.2.8
#   [717857b8] + DSP v0.8.4
#   [c8e1da08] + IterTools v1.10.0
#   [f27b6e38] + Polynomials v4.1.0
# Precompiling packages...
#     484.8 ms  ✓ IterTools
#    1170.3 ms  ✓ Bessels
#   11274.1 ms  ✓ Polynomials
#     793.8 ms  ✓ Polynomials → PolynomialsChainRulesCoreExt
#     929.0 ms  ✓ Polynomials → PolynomialsFFTWExt
#    2374.2 ms  ✓ DSP
#   6 dependencies successfully precompiled in 15 seconds. 410 already precompiled.

# %%
ca = Ca40([("S1/2", -1/2), ("D5/2", -1/2)])
print(typeof(ca) <: Ion)
# Out:
# true

# %%
ca = Ca40([("S1/2", -1/2, "S"), ("D5/2", -1/2, "D")])
print(ca)
# Out:
# ⁴⁰Ca
# ("S1/2", -1//2): "S"
# ("D5/2", -1//2): "D"

# %%
laser = Laser()
print(laser)
# Out:
# λ: missing m
# Δ: 0 Hz
# ̂ϵ: (x=0.7071067811865475, y=0.7071067811865475, z=0.0)
# k̂: (x=0, y=0, z=1)
# I(t=0): 0 W/m²
# ϕ(t=0): 0.0 ⋅ 2π

# %%
sublevelaliases(ca)
# Out:
# Dict{String, Tuple} with 2 entries:
#   "S" => ("S1/2", -1//2)
#   "D" => ("D5/2", -1//2)

# %%
chain = LinearChain(
        ions=[ca],
        comfrequencies=(x=3e6,y=3e6,z=1e6), 
        selectedmodes=(;z=[1])
    )
print(typeof(chain) <: IonTrap)
# Out:
# MethodError: no method matching Optim.Options(; g_abstol::Float64, g_reltol::Float64)
#
# Closest candidates are:
#   Optim.Options(; x_tol, f_tol, g_tol, x_abstol, x_reltol, f_abstol, f_reltol, g_abstol, outer_x_tol, outer_f_tol, outer_g_tol, outer_x_abstol, outer_x_reltol, outer_f_abstol, outer_f_reltol, outer_g_abstol, f_calls_limit, g_calls_limit, h_calls_limit, allow_f_increases, allow_outer_f_increases, successive_f_tol, iterations, outer_iterations, store_trace, trace_simplex, show_trace, extended_trace, show_warnings, show_every, callback, time_limit) got unsupported keyword argument "g_reltol"
#    @ Optim C:\Users\jewoo\.julia\packages\Optim\7krni\src\types.jl:71
#   Optim.Options(::T, ::T, ::T, ::T, ::T, ::T, ::T, ::T, ::T, ::T, ::Int64, ::Int64, ::Int64, ::Bool, ::Bool, ::Int64, ::Int64, ::Int64, ::Bool, ::Bool, ::Bool, ::Bool, ::Bool, ::Int64, ::TCallback, ::Float64) where {T, TCallback} got unsupported keyword arguments "g_abstol", "g_reltol"
#    @ Optim C:\Users\jewoo\.julia\packages\Optim\7krni\src\types.jl:43
#
#
# Stacktrace:
#  [1] kwerr(kw::@NamedTuple{g_abstol::Float64, g_reltol::Float64}, args::Type)
#    @ Base .\error.jl:165
#  [2] searchfor_trappingpotential_parameters(M::Vector{Float64}, Q::Vector{Int64}, target_eigenfrequencies::@NamedTuple{x::Float64, y::Float64, z::Float64})
#    @ IonSim C:\Users\jewoo\.julia\packages\IonSim\s9QSU\src\iontraps.jl:489
#  [3] searchfor_trappingpotential_parameters(ions::Vector{IonInstance{:Ca40}}, target_eigenfrequencies::@NamedTuple{x::Float64, y::Float64, z::Float64})
#    @ IonSim C:\Users\jewoo\.julia\packages\IonSim\s9QSU\src\iontraps.jl:520
#  [4] full_normal_mode_description(ions::Vector{IonInstance{:Ca40}}, comfreqs::@NamedTuple{x::Float64, y::Float64, z::Float64})
#    @ IonSim C:\Users\jewoo\.julia\packages\IonSim\s9QSU\src\iontraps.jl:558
#  [5] LinearChain(; ions::Vector{IonInstance{:Ca40}}, comfrequencies::@NamedTuple{x::Float64, y::Float64, z::Float64}, selectedmodes::@NamedTuple{z::Vector{Int64}}, N::Int64)
#    @ IonSim C:\Users\jewoo\.julia\packages\IonSim\s9QSU\src\iontraps.jl:99
#  [6] top-level scope
#    @ In[12]:1

# %%
Pkg.add("Revise")
Pkg.add("IonSim")
Pkg.add("QuantumOptics")
using Revise
using IonSim
using QuantumOptics: timeevolution, stochastic, Basis
# Out:
#    Resolving package versions...
#   No Changes to `C:\Users\jewoo\.julia\environments\v1.10\Project.toml`
#   No Changes to `C:\Users\jewoo\.julia\environments\v1.10\Manifest.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\jewoo\.julia\environments\v1.10\Project.toml`
#   No Changes to `C:\Users\jewoo\.julia\environments\v1.10\Manifest.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\jewoo\.julia\environments\v1.10\Project.toml`
#   No Changes to `C:\Users\jewoo\.julia\environments\v1.10\Manifest.toml`

# %%
using Pkg
Pkg.add("StochasticDiffEq")
Pkg.add("DSP")
# Out:
#    Resolving package versions...
#   No Changes to `C:\Users\jewoo\.julia\environments\v1.10\Project.toml`
#   No Changes to `C:\Users\jewoo\.julia\environments\v1.10\Manifest.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\jewoo\.julia\environments\v1.10\Project.toml`
#   No Changes to `C:\Users\jewoo\.julia\environments\v1.10\Manifest.toml`

# %%
ca = Ca40([("S1/2", -1/2), ("D5/2", -1/2)])
print(typeof(ca) <: Ion)
# Out:
# true

# %%
chain = LinearChain(
        ions=[ca],
        comfrequencies=(x=3e6,y=3e6,z=1e6), 
        selectedmodes=(;z=[1]),
    )
print(typeof(chain) <: IonTrap)
# Out:
# MethodError: no method matching LinearChain(; ions::Vector{IonInstance{:Ca40}}, comfrequencies::@NamedTuple{x::Float64, y::Float64, z::Float64}, selectedmodes::@NamedTuple{z::Vector{Int64}})
#
# Stacktrace:
#  [1] top-level scope
#    @ In[34]:1
